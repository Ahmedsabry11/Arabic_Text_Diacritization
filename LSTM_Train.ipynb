# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np
from torch.optim.lr_scheduler import StepLR
from torch.utils.data import Dataset, DataLoader
from LSTM import LSTMClassifier
from data_preprocessing import DataPreprocessing
from cbhg_data_loader import MyDataset

# %%
class LSTMTrainer:
    def __init__(self,load=True,epoch = 0,input_size = 39,hidden_size = 256,output_size = 16,batch_size = 64,num_epochs = 20,num_embeddings=300):
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.batch_size = batch_size
        self.num_epochs = num_epochs
        self.num_embeddings = num_embeddings

        self.device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
        
        self.model = LSTMClassifier(self.num_embeddings, self.hidden_size, self.output_size,self.num_embeddings)
        self.current_epoch = 0
        self.current_epoch = epoch
        if load:
            self.load_model(epoch)
        self.model.to(self.device)
        self.dataset = MyDataset(T = 280)
        self.test_dataset = MyDataset(dataset_path="dataset/test_preprocessed.txt",T = 280)
        self.train_dataloader = DataLoader(self.dataset, batch_size=self.batch_size, shuffle=True)
        self.test_dataloader = DataLoader(self.test_dataset, batch_size=self.batch_size, shuffle=True)
        self.criterion = nn.CrossEntropyLoss(ignore_index=15)
        self.optimizer = optim.Adam(self.model.parameters(), lr=0.001)
        self.scheduler = StepLR(self.optimizer, step_size=100, gamma=0.5)
        

    def train(self):
        for epoch in range(0,self.current_epoch):
            self.scheduler.step()
        for epoch in range(self.current_epoch,self.num_epochs):
            self.model.train()
            running_loss = 0.0
            for i, data in enumerate(self.train_dataloader, 0):
                # get the inputs
                inputs, labels = data
                inputs = inputs.to(self.device)
                labels = labels.to(self.device)
                # zero the parameter gradients
                self.optimizer.zero_grad()
                # forward + backward + optimize
                outputs = self.model(inputs)
                print(outputs.shape)
                outputs = outputs.view(-1, outputs.shape[-1])
                labels = labels.view(-1)
                loss = self.criterion(outputs, labels)
                loss.backward()
                torch.nn.utils.clip_grad_norm_(self.model.parameters(), 0.5)
                self.optimizer.step()
                # print statistics
                running_loss += loss.item()
                if i % 2 == 0:  # print every 100 mini-batches
                    print('[%d, %5d] loss: %.3f' %
                          (epoch + 1, i + 1, running_loss / 2))
                    running_loss = 0.0
            self.scheduler.step()
            # save the model if it has the best training loss till now
            self.save_model(epoch+1)
        print('Finished Training')

    def test(self):
        self.model.eval()
        with torch.no_grad():
            running_loss = 0.0
            for i, data in enumerate(self.test_dataloader, 0):
                # get the inputs
                inputs, labels = data
                inputs = inputs.to(self.device)
                labels = labels.to(self.device)
                # forward + backward + optimize
                outputs = self.model(inputs)
                outputs = outputs.view(-1, outputs.shape[-1])
                labels = labels.view(-1)
                loss = self.criterion(outputs, labels)
                running_loss += loss.item()
            print('Test loss: %.3f' %
                  (running_loss / len(self.test_dataloader)))
    def calcluate_accuracy(self):
        self.model.eval()
        with torch.no_grad():
            correct = 0
            total = 0
            for i, data in enumerate(self.test_dataloader, 0):
                # get the inputs
                inputs, labels = data
                inputs = inputs.to(self.device)
                labels = labels.to(self.device)
                # forward + backward + optimize
                outputs = self.model(inputs)
                outputs = outputs.view(-1, outputs.shape[-1])
                labels = labels.view(-1)
                _, predicted = torch.max(outputs.data, 1)
                      # cut the padding 
                predicted = predicted[labels != 15]
                labels = labels[labels != 15]
                total += labels.size(0)
                correct += (predicted == labels).sum().item()
            print('Accuracy of the network on the test set: %d %%' % (
                    100 * correct / total))
            print('Accuracy of the network on the test set: %f %%' % (
                    100 * correct / total))
        with torch.no_grad():
            correct = 0
            total = 0
            for i, data in enumerate(self.train_dataloader, 0):
                # get the inputs
                inputs, labels = data
                inputs = inputs.to(self.device)
                labels = labels.to(self.device)
                
                # forward + backward + optimize
                outputs = self.model(inputs)
                
                outputs = outputs.view(-1, outputs.shape[-1])
                labels = labels.view(-1)
                _, predicted = torch.max(outputs.data, 1)
                      # cut the padding 
                predicted = predicted[labels != 15]
                labels = labels[labels != 15]
                total += labels.size(0)
                correct += (predicted == labels).sum().item()
            print('Accuracy of the network on the train set: %d %%' % (
                    100 * correct / total))
            # print floating point accuracy
            print('Accuracy of the network on the train set: %f %%' % (
                    100 * correct / total))
    def save_model(self,epoch):
        torch.save(self.model.state_dict(), "models/lstm300_model_"+str(epoch)+".pth")
    def load_model(self,epoch=9):
        self.model.load_state_dict(torch.load("models/lstm_model_"+str(epoch)+".pth"))
        self.model.eval()
        self.current_epoch = epoch

# %%
lstmTrainer = LSTMTrainer(load=False)
lstmTrainer.train()
# Out:
# torch.Size([64, 280, 16])
# [1,     1] loss: 1.386
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [1,     3] loss: 2.691
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [1,     5] loss: 2.401
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [1,     7] loss: 2.158
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [1,     9] loss: 2.295
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [1,    11] loss: 1.879
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [1,    13] loss: 1.760
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [1,    15] loss: 1.695
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [1,    17] loss: 1.629
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [1,    19] loss: 1.620
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [1,    21] loss: 1.566
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [1,    23] loss: 1.503
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [1,    25] loss: 1.426
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [1,    27] loss: 1.351
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [1,    29] loss: 1.261
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [1,    31] loss: 1.208
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [1,    33] loss: 1.192
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [1,    35] loss: 1.145
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [1,    37] loss: 1.115
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [1,    39] loss: 1.104
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [1,    41] loss: 1.085
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [1,    43] loss: 1.065
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [1,    45] loss: 1.042
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [1,    47] loss: 1.029
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [1,    49] loss: 0.998
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [1,    51] loss: 0.977
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [1,    53] loss: 0.947
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [1,    55] loss: 0.914
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [1,    57] loss: 0.918
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [1,    59] loss: 0.895
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [1,    61] loss: 0.868
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [1,    63] loss: 0.885
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [1,    65] loss: 0.866
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [1,    67] loss: 0.858
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [1,    69] loss: 0.815
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [1,    71] loss: 0.814
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [1,    73] loss: 0.832
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [1,    75] loss: 0.791
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [1,    77] loss: 0.792
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [1,    79] loss: 0.751
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [1,    81] loss: 0.749
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [1,    83] loss: 0.742
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [1,    85] loss: 0.738
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [1,    87] loss: 0.735
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [1,    89] loss: 0.733
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [1,    91] loss: 0.713
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [1,    93] loss: 0.688
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [1,    95] loss: 0.689
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [1,    97] loss: 0.657
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [1,    99] loss: 0.665
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [1,   101] loss: 0.647
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [1,   103] loss: 0.625
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [1,   105] loss: 0.659
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [1,   107] loss: 0.607
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [1,   109] loss: 0.601
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [1,   111] loss: 0.606
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [1,   113] loss: 0.597
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [1,   115] loss: 0.594
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [1,   117] loss: 0.574
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [1,   119] loss: 0.556
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [1,   121] loss: 0.570
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [1,   123] loss: 0.569
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [1,   125] loss: 0.569
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [1,   127] loss: 0.556
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [1,   129] loss: 0.548
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [1,   131] loss: 0.556
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [1,   133] loss: 0.541
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [1,   135] loss: 0.540
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [1,   137] loss: 0.525
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [1,   139] loss: 0.514
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [1,   141] loss: 0.514
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [1,   143] loss: 0.521
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [1,   145] loss: 0.523
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [1,   147] loss: 0.504
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [1,   149] loss: 0.494
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [1,   151] loss: 0.473
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [1,   153] loss: 0.473
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [1,   155] loss: 0.479
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [1,   157] loss: 0.470
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [1,   159] loss: 0.460
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [1,   161] loss: 0.460
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [1,
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [18,   561] loss: 0.022
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [18,   563] loss: 0.019
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [18,   565] loss: 0.019
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [18,   567] loss: 0.020
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [18,   569] loss: 0.017
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [18,   571] loss: 0.019
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [18,   573] loss: 0.015
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [18,   575] loss: 0.022
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [18,   577] loss: 0.017
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [18,   579] loss: 0.015
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [18,   581] loss: 0.022
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [18,   583] loss: 0.017
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [18,   585] loss: 0.021
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [18,   587] loss: 0.019
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [18,   589] loss: 0.016
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [18,   591] loss: 0.019
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [18,   593] loss: 0.024
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [18,   595] loss: 0.020
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [18,   597] loss: 0.020
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [18,   599] loss: 0.020
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [18,   601] loss: 0.019
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [18,   603] loss: 0.018
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [18,   605] loss: 0.019
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [18,   607] loss: 0.019
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [18,   609] loss: 0.017
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [18,   611] loss: 0.019
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [18,   613] loss: 0.017
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [18,   615] loss: 0.021
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [18,   617] loss: 0.017
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [18,   619] loss: 0.018
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [18,   621] loss: 0.016
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [18,   623] loss: 0.020
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [18,   625] loss: 0.020
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [18,   627] loss: 0.019
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [18,   629] loss: 0.020
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [18,   631] loss: 0.016
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [18,   633] loss: 0.021
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [18,   635] loss: 0.020
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [18,   637] loss: 0.023
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [18,   639] loss: 0.020
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [18,   641] loss: 0.018
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [18,   643] loss: 0.019
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [18,   645] loss: 0.024
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [18,   647] loss: 0.021
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [18,   649] loss: 0.018
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [18,   651] loss: 0.019
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [18,   653] loss: 0.024
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [18,   655] loss: 0.021
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [18,   657] loss: 0.021
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [18,   659] loss: 0.021
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [18,   661] loss: 0.021
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [18,   663] loss: 0.023
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [18,   665] loss: 0.020
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [18,   667] loss: 0.019
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [18,   669] loss: 0.019
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [18,   671] loss: 0.016
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [18,   673] loss: 0.025
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [18,   675] loss: 0.022
# torch.Size([64, 280, 16])
# torch.Size([64, 280, 16])
# [18,   677] loss: 0.021
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-ae4c19b87598> in <module>
#       1 lstmTrainer = LSTMTrainer(load=False)
# ----> 2 lstmTrainer.train()
#
# <ipython-input-18-192e74b7c7aa> in train(self)
#      39                 self.optimizer.zero_grad()
#      40                 # forward + backward + optimize
# ---> 41                 outputs = self.model(inputs)
#      42                 print(outputs.shape)
#      43                 outputs = outputs.view(-1, outputs.shape[-1])
#
# c:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1108         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110             return forward_call(*input, **kwargs)
#    1111         # Do not call functions when jit is used
#    1112         full_backward_hooks, non_full_backward_hooks = [], []
#
# f:\Eman\Arabic_Text_Diacritization\LSTM.py in forward(self, input)
#      23         # print(input.shape)
#      24         output = self.char_embedding(input)
# ---> 25         output, _ = self.lstm(output)
#      26         output = self.linear(output)
#      27         return output
#
# c:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1108         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110             return forward_call(*input, **kwargs)
#    1111         # Do not call functions when jit is used
#    1112         full_backward_hooks, non_full_backward_hooks = [], []
#
# c:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\rnn.py in forward(self, input, hx)
#     759         self.check_forward_args(input, hx, batch_sizes)
#     760         if batch_sizes is None:
# --> 761             result = _VF.lstm(input, hx, self._flat_weights, self.bias, self.num_layers,
#     762                               self.dropout, self.training, self.bidirectional, self.batch_first)
#     763         else:
#
# KeyboardInterrupt:

# %%
lstmTrainer.calcluate_accuracy()
# Out:
# Accuracy of the network on the test set: 97 %
# Accuracy of the network on the test set: 97.507254 %
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-ac27163bda4a> in <module>
# ----> 1 lstmTrainer.calcluate_accuracy()
#
# <ipython-input-18-192e74b7c7aa> in calcluate_accuracy(self)
#     102             correct = 0
#     103             total = 0
# --> 104             for i, data in enumerate(self.train_dataloader, 0):
#     105                 # get the inputs
#     106                 inputs, labels = data
#
# c:\ProgramData\Anaconda3\lib\site-packages\torch\utils\data\dataloader.py in __next__(self)
#     528             if self._sampler_iter is None:
#     529                 self._reset()
# --> 530             data = self._next_data()
#     531             self._num_yielded += 1
#     532             if self._dataset_kind == _DatasetKind.Iterable and \
#
# c:\ProgramData\Anaconda3\lib\site-packages\torch\utils\data\dataloader.py in _next_data(self)
#     568     def _next_data(self):
#     569         index = self._next_index()  # may raise StopIteration
# --> 570         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     571         if self._pin_memory:
#     572             data = _utils.pin_memory.pin_memory(data)
#
# c:\ProgramData\Anaconda3\lib\site-packages\torch\utils\data\_utils\fetch.py in fetch(self, possibly_batched_index)
#      47     def fetch(self, possibly_batched_index):
#      48         if self.auto_collation:
# ---> 49             data = [self.dataset[idx] for idx in possibly_batched_index]
#      50         else:
#      51             data = self.dataset[possibly_batched_index]
#
# c:\ProgramData\Anaconda3\lib\site-packages\torch\utils\data\_utils\fetch.py in <listcomp>(.0)
#      47     def fetch(self, possibly_batched_index):
#      48         if self.auto_collation:
# ---> 49             data = [self.dataset[idx] for idx in possibly_batched_index]
#      50         else:
#      51             data = self.dataset[possibly_batched_index]
#
# f:\Eman\Arabic_Text_Diacritization\cbhg_data_loader.py in __getitem__(self, idx)
#      46         # sentence = torch.tensor(sentence, dtype=torch.float32)
#      47         sentence = torch.LongTensor(sentence)
# ---> 48         labels = torch.LongTensor(labels)
#      49
#      50         return sentence, labels
#
# KeyboardInterrupt:
